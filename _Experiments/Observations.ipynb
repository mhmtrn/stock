# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import stock_module as sm
import random
import os
import datetime
import time

# %% [markdown]
# ---
# #### KORDS

# %%
stock_name = "KORDS"
MA_days = [7, 14, 20, 50, 100, 200]
start_date = "01-10-2016"
end_date = "22-06-2020"
RSI_day = 14
trajectory_day = 14

# %%
frame = sm.whole_frame(stock_name, MA_days, start_date, end_date, RSI_day, trajectory_day)
# Out:
# /Users/mturan/Desktop/Scripts/stock_analysis/stock_module.py:1250: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f"{column}_CH"] = data[f"{column}"].pct_change()

# %%
frame.StockValue_momentum.plot(figsize=[30,7])

# %%
frame[["MA_14_CH", "MA_50_CH", "MA_100_CH"]].plot(figsize=(30,7))
plt.axhline(0, color="black")
plt.axvline(np.datetime64('2018-07-05'), color="red")
plt.axvline(np.datetime64('2018-11-01'), color="red")
plt.axvline(np.datetime64('2016-12-03'), color="darkred")
plt.axvline(np.datetime64('2017-06-01'), color="darkred")
plt.axvline(np.datetime64('2019-02-10'), color="darkred")
plt.axvline(np.datetime64('2019-05-25'), color="darkred")
plt.axvline(np.datetime64('2019-12-01'), color="red")
plt.axvline(np.datetime64('2020-03-04'), color="red")

# %%
frame[["StockValue"]].plot(figsize=(30,7))
plt.axvline(np.datetime64('2018-07-05'), color="red")
plt.axvline(np.datetime64('2018-11-01'), color="red")
plt.axvline(np.datetime64('2016-12-03'), color="darkred")
plt.axvline(np.datetime64('2017-06-01'), color="darkred")
plt.axvline(np.datetime64('2019-02-10'), color="darkred")
plt.axvline(np.datetime64('2019-05-25'), color="darkred")
plt.axvline(np.datetime64('2019-12-01'), color="red")
plt.axvline(np.datetime64('2020-03-04'), color="red")

# %%
frame[["market_positive_ma_5"]].plot(figsize=(30,7))
plt.axvline(np.datetime64('2018-07-05'), color="red")
plt.axvline(np.datetime64('2018-11-01'), color="red")
plt.axvline(np.datetime64('2016-12-03'), color="darkred")
plt.axvline(np.datetime64('2017-06-01'), color="darkred")
plt.axvline(np.datetime64('2019-02-10'), color="darkred")
plt.axvline(np.datetime64('2019-05-25'), color="darkred")
plt.axvline(np.datetime64('2019-12-01'), color="red")
plt.axvline(np.datetime64('2020-03-04'), color="red")

# %%
frame[["Drawdown"]].plot(figsize=(30,7))
plt.axvline(np.datetime64('2018-07-05'), color="red")
plt.axvline(np.datetime64('2018-11-01'), color="red")
plt.axvline(np.datetime64('2016-12-03'), color="darkred")
plt.axvline(np.datetime64('2017-06-01'), color="darkred")
plt.axvline(np.datetime64('2019-02-10'), color="darkred")
plt.axvline(np.datetime64('2019-05-25'), color="darkred")
plt.axvline(np.datetime64('2019-12-01'), color="red")
plt.axvline(np.datetime64('2020-03-04'), color="red")

# %% [markdown]
# ---
# #### THYAO

# %%
stock_name = "THYAO"
MA_days = [7, 14, 20, 50, 100, 200]
start_date = "01-10-2011"
end_date = "22-06-2016"
RSI_day = 14
trajectory_day = 14

# %%
frame = sm.whole_frame(stock_name, MA_days, start_date, end_date, RSI_day, trajectory_day)
# Out:
# /Users/mturan/Desktop/Scripts/stock_analysis/stock_module.py:1210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f"{column}_CH"] = data[f"{column}"].pct_change()

# %%
frame
# Out:
#                 MA_7   MA_7_CH     MA_14  MA_14_CH    MA_20  MA_20_CH  \
# 2011-10-14  2.238429 -0.004004  2.268979 -0.002151  2.29690  0.001269
# 2011-10-17  2.237200 -0.003417  2.265921 -0.002434  2.28749  0.000638
# 2011-10-18  2.234757 -0.003197  2.257364 -0.002909  2.27423 -0.000207
# 2011-10-19  2.227429 -0.002908  2.243929 -0.003557  2.26055 -0.001132
# 2011-10-20  2.207886 -0.003009  2.228657 -0.003987  2.24772 -0.001897
# ...              ...       ...       ...       ...      ...       ...
# 2016-06-15  5.941429 -0.002766  6.071429 -0.002980  6.10000 -0.004153
# 2016-06-16  5.890000 -0.003269  6.040714 -0.002954  6.08150 -0.003917
# 2016-06-17  5.837143 -0.004274  5.997143 -0.003154  6.06550 -0.003788
# 2016-06-20  5.795714 -0.005077  5.965000 -0.003186  6.04650 -0.003665
# 2016-06-21  5.798571 -0.005009  5.950000 -0.002965  6.02950 -0.003597
#
#                MA_50  MA_50_CH    MA_100  MA_100_CH    MA_200  MA_200_CH  \
# ...

# %%
frame[["MA_14_CH", "MA_50_CH", "MA_100_CH"]].plot(figsize=(30,7))
plt.axhline(0, color="black")
# plt.axvline(np.datetime64('2015-09-10'), color="darkred")
# plt.axvline(np.datetime64('2015-09-30'), color="darkred")
plt.axhline(-0.005, color="red")

# %%
frame[["StockValue"]].plot(figsize=(30,7))

# plt.axvline(np.datetime64('2015-09-10'), color="darkred")
# plt.axvline(np.datetime64('2015-09-30'), color="darkred")

# %%
frame[["Drawdown"]].plot(figsize=(30,7))
plt.axvline(np.datetime64('2016-03-01'), color="red")
plt.axvline(np.datetime64('2016-04-21'), color="red")
plt.axvline(np.datetime64('2016-08-10'), color="darkred")
plt.axvline(np.datetime64('2016-11-13'), color="darkred")
plt.axvline(np.datetime64('2016-12-23'), color="red")
plt.axvline(np.datetime64('2017-03-07'), color="red")
plt.axvline(np.datetime64('2017-04-25'), color="darkred")
plt.axvline(np.datetime64('2017-06-22'), color="darkred")

# %% [markdown]
# ---
# #### TKFEN

# %%
stock_name = "TKFEN"
MA_days = [7, 14, 20, 50, 100, 200]
start_date = "01-10-2015"
end_date = "22-06-2020"
RSI_day = 14
trajectory_day = 14

# %%
frame = sm.whole_frame(stock_name, MA_days, start_date, end_date, RSI_day, trajectory_day)
# Out:
# /Users/mturan/Desktop/Scripts/stock_analysis/stock_module.py:1210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f"{column}_CH"] = data[f"{column}"].pct_change()

# %%
frame[["MA_14_CH", "MA_50_CH", "MA_100_CH"]].plot(figsize=(30,7))
plt.axhline(0, color="black")
plt.axhline(-0.005, color="red")

# %%
frame[["StockValue"]].plot(figsize=(30,7))

# %% [markdown]
# ---
# #### INDES

# %%
stock_name = "INDES"
MA_days = [7, 14, 20, 50, 100, 200]
start_date = "01-10-2015"
end_date = "22-06-2020"
RSI_day = 14
trajectory_day = 14

# %%
frame = sm.whole_frame(stock_name, MA_days, start_date, end_date, RSI_day, trajectory_day)
# Out:
# /Users/mturan/Desktop/Scripts/stock_analysis/stock_module.py:1210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f"{column}_CH"] = data[f"{column}"].pct_change()

# %%
frame[["MA_14_CH", "MA_50_CH", "MA_100_CH"]].plot(figsize=(30,7))
plt.axhline(0, color="black")
plt.axhline(-0.005, color="red")

# %%
frame[["StockValue"]].plot(figsize=(30,7))

# %% [markdown]
# ---
# #### CIMSA

# %%
stock_name = "CIMSA"
MA_days = [7, 14, 20, 50, 100, 200]
start_date = "01-10-2015"
end_date = "22-06-2020"
RSI_day = 14
trajectory_day = 14

# %%
frame = sm.whole_frame(stock_name, MA_days, start_date, end_date, RSI_day, trajectory_day)
# Out:
# /Users/mturan/Desktop/Scripts/stock_analysis/stock_module.py:1210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f"{column}_CH"] = data[f"{column}"].pct_change()

# %%
frame[["MA_14_CH", "MA_50_CH", "MA_100_CH"]].plot(figsize=(30,7))
plt.axhline(0, color="black")

# %%
frame[["StockValue"]].plot(figsize=(30,7))

# %% [markdown]
# ---
# #### ******

# %%
# iki yıl öncesine giderek geriye doğru referans alalım
sm.filter_financials(["turnover", "ebit", "gross_profit_margin"], 12, 3, 5)
# Out:
# Reference year to move back: 2014/12
# Reference year to move back: 2014/12
# Reference year to move back: 2014/12
# ['SAFKR',
#  'FORMT',
#  'MPARK',
#  'TBORG',
#  'PEKGY',
#  'VERTU',
#  'SMART',
#  'TDGYO',
#  'TURGG',
#  'PAGYO',
#  'DERAS',
#  'YGGYO',
#  'OZRDN',
#  'KFEIN',
#  'AKCNS',
#  'UFUK',
#  'MGROS',
#  'ASLAN',
#  'YKSLN',
#  'MAVI',
#  'TLMAN',
#  'BRISA',
#  'ENJSA',
#  'KERVT',
#  'BASCM',
#  'CEOEM',
#  'NATEN',
#  'ARENA',
#  'SOKM',
#  'JANTS',
#  'MSGYO']

# %%
stock_name = "DEVA"
MA_days = [7, 14, 20, 50, 100, 200]
start_date = "01-04-2015"
end_date = "22-06-2020"
RSI_day = 14
trajectory_day = 14

# %%
frame = sm.whole_frame(stock_name, MA_days, start_date, end_date, RSI_day, trajectory_day)
# Out:
# /Users/mturan/Desktop/Scripts/stock_analysis/stock_module.py:1250: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f"{column}_CH"] = data[f"{column}"].pct_change()

# %%
frame = frames[37]
frame = frame.loc[frame.index > "01-01-2015"]
frame = frame.loc[frame.index < "01-01-2018"]
frame["stock_name"][0]
# Out:
# 'DMSAS'

# %%
frame[["MA_200_CH", "MA_100_CH", "MA_50_CH", "MA_14_CH"]].plot(figsize=(30,7))
plt.axhline(0, color="black")
plt.axvline(frame.iloc[334:,:].index[0], color="black")
plt.axvline(frame.iloc[420:,:].index[0], color="black")
plt.axvline(frame.iloc[440:,:].index[0], color="red")
plt.axvline(frame.iloc[567:,:].index[0], color="red")
plt.axvline(frame.iloc[569:,:].index[0], color="black")
plt.axvline(frame.iloc[582:,:].index[0], color="black")

# %%
frame[["StockValue"]].plot(figsize=(30,7))
plt.axvline(frame.iloc[334:,:].index[0], color="black")
plt.axvline(frame.iloc[420:,:].index[0], color="black")
plt.axvline(frame.iloc[440:,:].index[0], color="red")
plt.axvline(frame.iloc[567:,:].index[0], color="red")
plt.axvline(frame.iloc[569:,:].index[0], color="black")
plt.axvline(frame.iloc[582:,:].index[0], color="black")

# %%
frame[["MA_14", "MA_50", "MA_200"]].plot(figsize=(30,7))
plt.axvline(frame.iloc[334:,:].index[0], color="black")
plt.axvline(frame.iloc[420:,:].index[0], color="black")

# %%
# MA_100_CH 0'dan büyük ve MA_14_CH de -0.05'ten büyükse
frame['day'] = np.where((frame['MA_200_CH'] > -0.001) &
                        (frame['MA_100_CH'] > -0.002) &
                        (frame['MA_50_CH'] > -0.003) &
                        (frame['MA_14_CH'] > -0.004) &
                        (frame['MA_14'] > frame['MA_100']) &
                        (frame['MA_50'] > frame['MA_200']) &
                        (frame['RSI'] > 35)
                        , "BUY", "SELL")

# ma_14_ch değerini volatilitesine göre belirle

# %%
locations = []
start = 0
for row in range(frame.shape[0]-1):
    if frame.day[row] == "BUY":
        mode = "BUY"
        if (frame.day[row] == "BUY" and frame.day[row+1] == "SELL"):
            end = row
            loc = [start, end]
            locations.append(loc)

    else:
        mode = "SELL"
        if (frame.day[row] == "SELL" and frame.day[row+1] == "BUY"):
            start = row+1

# %%
locations
# Out:
# [[0, 17],
#  [24, 26],
#  [28, 42],
#  [102, 107],
#  [228, 244],
#  [247, 265],
#  [267, 281],
#  [306, 336],
#  [340, 340],
#  [343, 377],
#  [379, 395],
#  [397, 400],
#  [407, 409],
#  [554, 571],
#  [573, 573],
#  [590, 609],
#  [611, 626],
#  [631, 631],
#  [633, 652],
#  [660, 660],
#  [676, 685],
#  [691, 716]]

# %%
frame.iloc[335:344,:]
# Out:
#                 MA_7   MA_7_CH     MA_14  MA_14_CH     MA_20  MA_20_CH  \
# 2016-04-27  0.919071  0.002136  0.935229  0.005095  0.922780  0.004889
# 2016-04-28  0.920971  0.001751  0.935707  0.004665  0.926440  0.004786
# 2016-04-29  0.922871  0.000690  0.932857  0.003634  0.929435  0.004469
# 2016-05-02  0.925714 -0.000278  0.929529  0.002575  0.930765  0.003945
# 2016-05-03  0.922857 -0.001156  0.924300  0.001530  0.930430  0.003434
# 2016-05-04  0.920957 -0.001737  0.921921  0.000859  0.930760  0.003111
# 2016-05-05  0.917157 -0.002463  0.918593  0.000153  0.929095  0.002610
# 2016-05-06  0.910500 -0.003125  0.914786 -0.000550  0.926765  0.002086
# 2016-05-09  0.903843 -0.003576  0.912407 -0.000957  0.922775  0.001408
#
#                MA_50  MA_50_CH    MA_100  MA_100_CH  ...        RSI  Drawdown  \
# 2016-04-27  0.861964  0.002885  0.843336   0.001091  ...  52.363897 -0.166309
# 2016-04-28  0.865158  0.002989  0.844334   0.001078  ...  52.397996 -0.160311
# ...

# %%
total = 0
for obs in locations:
    total += obs[1] - obs[0]
print(f"total transaction day: {total}")
print(f"total day            : {frame.shape[0]}")
# Out:
# total transaction day: 275
# total day            : 757

# %%
rets = []
for obs in locations:
    ret = (frame.StockValue[obs[1]] - frame.StockValue[obs[0]]) / frame.StockValue[obs[0]]
    rets.append(ret)
    print(ret)
# Out:
# -0.014592478348558521
# 0.0
# -0.014918132201334115
# -0.02431870951973607
# 0.0
# -0.007992365501610449
# -0.023929773929773964
# 0.10157350868952562
# 0.0
# 0.08816601233875491
# -0.02896608597051852
# 0.02961011591148579
# -0.022980958634274358
# -0.07407797681770276
# 0.0
# 0.2791133656815173
# 0.012011244569384107
# 0.0
# 0.17221212360704968
# 0.0
# -0.049264190609670654
# 0.4171167744389502

# %%
rets = [ret + 1 for ret in rets]

# %%
retur = 1
for ret in rets:
    retur = retur * ret
retur
# Out:
# 2.032598546465875

# %% [markdown]
# ---

# %%
for i in range(len(frames)):
    frame = frames[i]
    frame = frame.loc[frame.index > "01-01-2015"]
    frame = frame.loc[frame.index < "01-01-2020"]
    
    # MA_100_CH 0'dan büyük ve MA_14_CH de -0.05'ten büyükse
    frame['day'] = np.where((frame['MA_200_CH'] > -0.001) &
                            (frame['MA_100_CH'] > -0.002) &
                            (frame['MA_50_CH'] > -0.003) &
                            (frame['MA_14_CH'] > -0.004) &
                            (frame['MA_14'] > frame['MA_100']) &
                            (frame['MA_50'] > frame['MA_200']) &
                            (frame['RSI'] > 50)
                            , "BUY", "SELL")

    locations = []
    start = 0
    for row in range(frame.shape[0]-1):
        if frame.day[row] == "BUY":
            mode = "BUY"
            if (frame.day[row] == "BUY" and frame.day[row+1] == "SELL"):
                end = row
                loc = [start, end]
                locations.append(loc)

        else:
            mode = "SELL"
            if (frame.day[row] == "SELL" and frame.day[row+1] == "BUY"):
                start = row+1
                
    total = 0
    for obs in locations:
        total += obs[1] - obs[0]
        
    rets = []
    for obs in locations:
        ret = (frame.StockValue[obs[1]] - frame.StockValue[obs[0]]) / frame.StockValue[obs[0]]
        rets.append(ret)
        
    rets = [ret + 1 for ret in rets]
    
    retur = 1
    returs = [] 
    for ret in rets:
        retur = retur * ret
        returs.append(retur)
print(np.array(returs).mean())
# Out:
# 1.6109853072899172

# %% [markdown]
# ---

# %%
MA_days = [7, 14, 20, 50, 100, 200]
start_date = "01-04-2015"
end_date = "22-06-2020"
RSI_day = 14
trajectory_day = 14

# %%
frames = []
for stock_name in list(ortak_olmayanlar)[:]:
    try:
        frame = sm.whole_frame(stock_name, MA_days, start_date, end_date, RSI_day, trajectory_day)
        frames.append(frame)
    except:
        print(stock_name)
# Out:
# YKSLN
# /Users/mturan/Desktop/Scripts/stock_analysis/stock_module.py:1250: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f"{column}_CH"] = data[f"{column}"].pct_change()
# /Users/mturan/Desktop/Scripts/stock_analysis/stock_module.py:1250: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f"{column}_CH"] = data[f"{column}"].pct_change()
# /Users/mturan/Desktop/Scripts/stock_analysis/stock_module.py:1250: SettingWithCopyWarning:
# ...

# %%
len(frames)
# Out:
# 201

# %%
frames_ = pd.concat(frames)

# %%
frames_.to_pickle("frames_whole")

# %%
frames_.shape
# Out:
# (244693, 21)

# %%
len(stockNames)
# Out:
# 404

# %%
framess = pd.read_pickle("frames_whole")

# %%
framess2 = pd.read_pickle("frames_whole_SUM")

# %%
final_frame = pd.concat([framess, framess2])

# %%
final_frame.to_pickle("frames_whole_FINAL")

# %%
len(list(set(final_frame["stock_name"])))
# Out:
# 400

# %%
stockNames
# Out:
# ['AVOD',
#  'OYAYO',
#  'ATAGY',
#  'ERBOS',
#  'ATLAS',
#  'BOSSA',
#  'DAGHL',
#  'DAGI',
#  'DOAS',
#  'SUMAS',
#  'GYHOL',
#  'MRSHL',
#  'YESIL',
#  'AGYO',
#  'DURDO',
#  'MGROS',
#  'VKING',
#  'ACSEL',
#  'GLYHO',
#  'KRDMA',
#  'MAKTK',
#  'POLTK',
#  'SANFM',
#  'GARFA',
#  'RYSAS',
#  'EMKEL',
#  'ALBRK',
#  'BAGFS',
#  'BMELK',
#  'DENCM',
#  'EPLAS',
#  'AVISA',
#  'ECILC',
#  'AYGAZ',
#  'TURGG',
#  'DGKLB',
#  'SARKY',
#  'DMSAS',
#  'POLHO',
#  'ISATR',
#  'BRISA',
#  'DESPC',
#  'EGGUB',
#  'RODRG',
#  'LKMNH',
#  'FMIZP',
#  'YKBNK',
#  'TKURU',
#  'PINSU',
#  'TMSN',
#  'PRKME',
#  'VESBE',
#  'UFUK',
#  'NATEN',
#  'ISFIN',
#  'TCELL',
#  'DGGYO',
#  'HALKS',
#  'GLRYH',
#  'ISBIR',
#  'MZHLD',
#  'AYCES',
#  'KOZAL',
#  'HEKTS',
#  'UZERB',
#  'DOBUR',
#  'KENT',
#  'OYLUM',
#  'BRKSN',
#  'TUPRS',
#  'AKBNK',
#  'KARSN',
#  'NUHCM',
#  'KORDS',
#  'IDEAS',
#  'MARKA',
#  'ARENA',
#  'OZKGY',
#  'TOASO',
#  'PGSUS',
#  'EKIZ',
#  'AGHOL',
#  'BJKAS',
#  'IEYHO',
# ...

# %%
ortak_olmayanlar = set(stockNames).symmetric_difference(set(framess["stock_name"])) # symmetric_difference metodu

# %%
len(ortak_olmayanlar)
# Out:
# 205

# %%
ortak_olmayanlar
# Out:
# {'ADEL',
#  'ADESE',
#  'AEFES',
#  'AFYON',
#  'AKCNS',
#  'AKENR',
#  'AKFGY',
#  'AKGRT',
#  'AKGUV',
#  'AKSA',
#  'AKSEN',
#  'AKSGY',
#  'ALARK',
#  'ALCAR',
#  'ALCTL',
#  'ALGYO',
#  'ALKA',
#  'ALYAG',
#  'ANACM',
#  'ANSGR',
#  'ARDYZ',
#  'ARMDA',
#  'ARSAN',
#  'ASELS',
#  'ASUZU',
#  'ATEKS',
#  'AVGYO',
#  'AVHOL',
#  'AYEN',
#  'BAKAB',
#  'BALAT',
#  'BANVT',
#  'BAYRK',
#  'BEYAZ',
#  'BIMAS',
#  'BLCYT',
#  'BNTAS',
#  'BRKO',
#  'BRMEN',
#  'BRSAN',
#  'BURCE',
#  'BURVA',
#  'CCOLA',
#  'CELHA',
#  'CEMTS',
#  'CEOEM',
#  'CLEBI',
#  'CMBTN',
#  'CMENT',
#  'CRDFA',
#  'CRFSA',
#  'CUSAN',
#  'DARDL',
#  'DERAS',
#  'DERIM',
#  'DESA',
#  'DEVA',
#  'DGATE',
#  'DITAS',
#  'DOCO',
#  'DOGUB',
#  'DOHOL',
#  'DOKTA',
#  'DYOBY',
#  'ECZYT',
#  'EGCYH',
#  'EGCYO',
#  'EGEEN',
#  'EGSER',
#  'EKGYO',
#  'ENKAI',
#  'EREGL',
#  'ERSU',
#  'ETYAT',
#  'EUHOL',
#  'EUKYO',
#  'FENER',
#  'FLAP',
#  'FONET',
#  'FORMT',
#  'GLBMD',
#  'GOODY',
#  'GOZDE',
#  'GSDDE',
# ...
